# %% [markdown]
# <a href="https://colab.research.google.com/github/AKSHARA123-UI/Flask_API/blob/main/Sales_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

df = pd.read_csv("sales.csv")
df.head()
# Out:
#          DATE  PRODUCT REGION  SALES
# 0  2025-01-01   Mobile  South  12000
# 1  2025-01-02   Laptop  North  45000
# 2  2025-01-03  Tablet    East  22000
# 3  2025-01-04   Mobile   West  15000
# 4  2025-01-05   Laptop  South  33000

# %%
df.head()
# Out:
#          DATE  PRODUCT REGION  SALES
# 0  2025-01-01   Mobile  South  12000
# 1  2025-01-02   Laptop  North  45000
# 2  2025-01-03  Tablet    East  22000
# 3  2025-01-04   Mobile   West  15000
# 4  2025-01-05   Laptop  South  33000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATE     10 non-null     object
#  1   PRODUCT  10 non-null     object
#  2   REGION   10 non-null     object
#  3   SALES    10 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 452.0+ bytes

# %%
df.describe()
# Out:
#               SALES
# count     10.000000
# mean   24200.000000
# std    11650.464941
# min    12000.000000
# 25%    16250.000000
# 50%    20000.000000
# 75%    30250.000000
# max    45000.000000

# %%
print(df.head(10))
print("\nColumn dtypes:\n", df.dtypes)
print("\nColumn names (with repr to reveal spaces):")
for c in df.columns:
    print(repr(c))
# Out:
#          DATE  PRODUCT REGION  SALES
# 0  2025-01-01   Mobile  South  12000
# 1  2025-01-02   Laptop  North  45000
# 2  2025-01-03  Tablet    East  22000
# 3  2025-01-04   Mobile   West  15000
# 4  2025-01-05   Laptop  South  33000
# 5  2025-01-06  Tablet   North  19000
# 6  2025-01-07   Mobile   East  17000
# 7  2025-01-08   Laptop   West  42000
# 8  2025-01-08  Tablet   South  21000
# 9  2025-01-09   Mobile  North  16000
#
# Column dtypes:
#  DATE       object
# PRODUCT    object
# REGION     object
# SALES       int64
# dtype: object
#
# Column names (with repr to reveal spaces):
# 'DATE'
# 'PRODUCT'
# 'REGION'
# 'SALES'

# %%
df['SALES'].sum()
# Out:
# np.int64(242000)

# %%
df.groupby('REGION')['SALES'].sum()
# Out:
# REGION
# East     39000
# North    80000
# South    66000
# West     57000
# Name: SALES, dtype: int64

# %%
df.groupby('PRODUCT')['SALES'].sum().plot(kind='bar')
plt.title('SALES by PRODUCT')
plt.xlabel('PRODUCT')
plt.ylabel('SALES')
plt.show()

# %%
df['SALES'].max()
# Out:
# 45000

# %%
df['SALES'].min()
# Out:
# 12000

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
import matplotlib.pyplot as plt

# Group sales by date
daily_sales = df.groupby('date')['sales'].sum()

# Plot
plt.figure(figsize=(10,5))
daily_sales.plot(kind='line', marker='o')

plt.title('Sales Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

df.groupby('region')['sales'].sum().plot(kind='pie', autopct='%1.1f%%')

plt.title('Sales Distribution by Region')
plt.ylabel('')   # removes the y-label
plt.show()
